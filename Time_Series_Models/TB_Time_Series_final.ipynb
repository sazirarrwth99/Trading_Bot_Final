# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /Users/noel/opt/anaconda3/lib/python3.9/site-packages (0.1.87)
# Requirement already satisfied: requests>=2.26 in /Users/noel/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/noel/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pandas>=0.24.0 in /Users/noel/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.4.2)
# Requirement already satisfied: lxml>=4.5.1 in /Users/noel/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (4.8.0)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/noel/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: numpy>=1.15 in /Users/noel/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/noel/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/noel/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24.0->yfinance) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/noel/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->yfinance) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/noel/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/noel/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/noel/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/noel/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas_datareader.data as web
from datetime import datetime, timedelta
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np
import warnings
import pandas as pd
from pandas import datetime
from datetime import timedelta
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
register_matplotlib_converters()
from time import time
warnings.filterwarnings("ignore")
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import pacf
from datetime import date
from datetime import datetime
import yfinance as yf
# Out:
# /var/folders/bk/zfnnqlb13tb44jdtl1wvzrn00000gn/T/ipykernel_4749/2708827875.py:10: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
#Funktion zur Berechnung der Trading-Gebühren 
def trading_fee(endowment):
    fee = endowment*(order_fee/100)
    
    #Prüfung, ob Mindest- oder Maximalgebühr des ausgewählten Brokers greift
    if fee <= min_:
        fee = min_
        
    if max_.isnumeric():
        if fee >= max_:
            fee = max_
        
    return fee

# %%
#Auswahl des Trading-Brokers
broker_auswahl = pd.read_csv('Trading_Broker.csv')

broker = str(input("Gewünschter Online-Broker: "))
print(broker)

i = broker_auswahl[broker_auswahl['Anbieter'] == broker].index
print(i[0])

print(broker_auswahl.at[i[0], "Gebühr"])
order_fee = broker_auswahl.at[i[0], "Gebühr"]
min_ = broker_auswahl.at[i[0], "Minimum"]
max_= broker_auswahl.at[i[0], "Maximum"]
# Out:
# Gewünschter Online-Broker:  IG
# IG
# 1
# 0.05

# %%
#Nutzerentscheidung, ob Short-Selling aktiviert werden soll -> Eingabe: "Yes" oder "No"
short = False
answer = str(input("Include short-selling?: "))
print(answer)
if answer == "Yes":
    short = True
# Out:
# Include short-selling?:  Yes
# Yes

# %%
#Funktion zum Download der relevanten Daten
def get_data(asset, start, end):
    ticker = asset
    data = yf.download(ticker, start=start, end=end)

    # calculate returns and format df
    data["Returns"] = 100 * data["Adj Close"].pct_change()
    data["Log. Returns"] = np.log(1+(data["Returns"]/100))
    data = data.dropna()
    data["Date"] = pd.to_datetime(data.index)

    data.reset_index(drop=True,inplace=True)
    return data

# %%
#Funktion, welche das betrachtete Zeitfenster in den Test-Datensatz (alle Tage aus der aktuellste) und den "Trainings"-Datensatz aufteilt (mit diesem Wert wird die Vorhersagegüte und die Endowment-Entwicklung berechnet)
def split_one_day(data):
    df_train, df_test = data.iloc[:-1], data.iloc[-1:]
    return df_train, df_test

# %%
#Funktion zur Durchführung der statistischen Auswertung der PACF und der optimalen Lag-Anzahl 
def statistic_tests(test_data, number_lags):
    trading = True
    AIC = []
    BIC = []
    a, ci = pacf(test_data, nlags=number_lags, alpha=0.01)
    centered_ci = ci - a[:,None]
    outside = np.abs(a) >= centered_ci[:,1]
    inside = ~outside
    ar_orders = [j for j, x in enumerate(outside) if x]
    #highest_lag = 0
    highest_lag = ar_orders[-1]
    if all(item == 0 for item in ar_orders): #falls nur lag = 0 signifikant (ist immer der Fall) wird nicht getradet 
        trading = False
        lag = 0
    else: #hier wird über das BIC die optimale Lag-Anzahl ausgewertet, alternativ kann man auch das AIC verwenden
        for ar_order in ar_orders:
            model_AR = ARIMA(test_data, order = (ar_order,0,ar_order))
            results_AR = model_AR.fit()
            AIC.append(results_AR.aic)
            BIC.append(results_AR.bic)
        min_value = min(BIC) 
        min_index=BIC.index(min_value)
        lag = ar_orders[min_index]
        
    return lag, trading, highest_lag #gibt den boolschen Parameter "trading" zurück, der bestimmt, ob an Tag X getradet wird (in Kombination mit aduller siehe unten), die optimale Lag-Anzahl ist im Parameter "Lag" gespeichert

# %%
#Funktion die prüft ob betrachtetes Zeitfenster stationär ist, gibt entsprechend boolschen Parameter zurück
def adfuller_test(data):
    stationary = False
    results_adfuller = adfuller(data)
    x = results_adfuller[0]
    y = results_adfuller[4]["1%"]
    #Hier wird nun geprüft ob Null-Hypothese der Nicht-Stationarität abgelehnt werden kann
    if x <= y:
        stationary = True
    if x > y:
        stationary = False

    return stationary

# %%
#In dieser Funktion findet das eigentliche Trading und die zugehörigen Berechnungen statt
def trade(training, testing, endowment, profit, cash, gewinn, counter_right, counter_general):
    history = [x for x in training["Log. Returns"]]
    real_returns = []
    forecasts = []
    tax_allowance = 801 #Definition der Steuerfreibetragsgrenze

    #In diesem Abschnitt wir der Forecast auf Basis der optimalen Lags der Forecast des ARIMA-Modells bestimmt. Außerdem werden weitere benötigte Parameter bestimmt.
    lag, trading, highest_lag = statistic_tests(history, number_lags)
    model = ARIMA(history, order = (lag,0,lag))
    model_results = model.fit()
    pred = model_results.forecast()
    forecast = pd.DataFrame(pred)
    forecast = forecast[0].iloc[0]
    real_return = testing["Returns"]
    if isinstance(real_return, float) == False:
        real_return = real_return.item()
    forecasts.append(forecast)
    stationary = adfuller_test(history)
    
    prev_endowment = endowment #Variable zur Berechnung der Gewinne aus aktuellem Trade
        
    if (trading == True) and (stationary== True): #getradet wird nur falls sowohl signifikante Ergebnisse aus der PACF erhalten wurden und die Datenreihe stationär ist
        #Counter_general berechnet, wie oft insgesamt getradet wird, counter_right berechnet, wie oft die Trading-Entscheidung korrekt ist
        counter_general = counter_general + 1
        
        # 1.Fall: BUY STOCK
        if forecast >= 0.0 and cash == True:
            #HINWEIS: falls die Broker-Gebühren-Datei vorhanden ist kann "0.0005*endowment" durch "trading_fee(endowment)" ersetzt werden
            endowment = endowment*(real_return/100+1) - 0.0005*endowment #trading_fee(endowment)
            action.append("BUY")
            cash = False
            if real_return >= 0.0:
                counter_right = counter_right + 1
            
        #2. Fall: HOLD STOCK
        elif forecast >= 0.0 and cash == False:
            endowment = endowment*(real_return/100+1) #Vermögen entwickelt sich abhängig von Aktienkursentwicklung
            action.append("HOLD")
            cash = False
            if real_return >= 0.0:
                counter_right = counter_right + 1
            
        #3. Fall: HOLD CASH or SHORT-SELLING
        elif forecast <= 0.0 and cash == True:
            if real_return <= 0.0:
                counter_right = counter_right + 1
            if short == True: #Falls short-selling ausgewählt wurde
                endowment = endowment - (real_return/100)*endowment - 0.0005*endowment #trading_fee(endowment)
                gain = endowment - prev_endowment
                if isinstance(gain, float) == False: #die isinstance-Abfragen (auch die weiter unten) werden nur gemacht weil es bei den folgenden if-Abfragen sonst zu Fehlermeldungen wegen dem zugehörigen Index kommt 
                    gain = gain.item()
                if gain > 0.0:
                    profit = profit + gain
                    #Falls der Gewinn 801 GE noch nicht übersteigt, wird der volle Gewinn aus diesem Trade angerechnet. Andernfalls werden die Kapitalertragssteuern + Soli (und ggf. Kirchensteuer) abgezogen 
                    if profit < 801:
                        endowment = endowment + gain
                    else:
                        endowment = endowment + (1-0.26375)*gain
                action.append("SHORT")
                cash == True
            else: #Falls Short-Selling verneint wurde bleibt Endowment unverändert
                endowment = endowment
                action.append("HOLD")
                cash = True
                
        #4. Fall: SELL STOCK
        elif forecast <= 0.0 and cash == False:
            if real_return <= 0.0:
                counter_right = counter_right + 1
            endowment = endowment - 0.0005*endowment  #trading_fee(endowment)
            gain = endowment - prev_endowment
            if isinstance(gain, float) == False:
                gain = gain.item()
            if gain >= 0:
                profit = profit + gain
                if profit < 801:
                    endowment = endowment + gain
                else:
                    endowment = endowment + (1-0.26375)*gain
            action.append("SELL")
            cash = True
            
    else: #Falls nicht getradet wird:
        if cash == True:
            action.append("No trade today, do nothing")
            endowment = endowment
        #Falls im Voraus getradet wurde, nun aber nicht mehr, werden Aktien verkauft, denn wann sich nächstes signifikantes Zeitfenster ergibt ist ungewiss. 
        #Die Aktien wären so ohne Einfluss des ARIMA-Modells den Schwankungen ausgesetzt. Dies soll verhindert werden. Dieses Vorgehen ist allerdings präferenzabhängig.
        if cash == False:
            action.append("No trade today, sell stocks")
            endowment = endowment - 0.0005*endowment #*(real_return/100+1)
            cash = True
    
    if (isinstance(endowment, float) == False) and (isinstance(endowment, int) == False): #dies dient erneut nur dazu den reinen Endowment-Wert ohne Index zu erhalten, damit Vergleich unten klappt
        endowment = endowment.item()
        
    #Hier wird Gewinnabschöpfung vorgenommen, ebenfalls präferenzabhängig    
    if endowment >= start_endowment:
        gewinn = gewinn + (endowment-start_endowment)
        endowment = 10000.0
    
    return endowment, action, profit, cash, gewinn, counter_right, counter_general

# %%
today = date.today()

#Verwendete Aktien:
stocks = ["AAPL", "MSFT", "GOOG", "AMZN", "JNJ", "UNH", "XOM", "V", "TCEHY", "JPM", "MC.PA", "WMT", "TSM", "NVDA", "PG", "LLY", "TSLA", "MA", "CVX", "NESN.SW", "HD", "ABBV", "META", "MRK", "BRK-B", "PFE", "BAC", "BABA", "KO", "ROG.SW", "PEP", "AVGO", "NVO", "ASML", "ORCL", "TM", "NOVN.SW", "AZN", "COST", "TMO", "BP", "OR.PA", "SHEL", "CSCO", "MCD", "ABT", "TMUS", "DHR", "RMS.PA", "ACN", "VZ", "DIS", "NEE", "BHP", "TTE", "CMCSA", "WFC", "PM", "TXN", "NKE", "LIN.DE", "BMY", "0939.HK", "SCHW", "RTX", "MS", "COP", "AMGN", "CDI.PA", "HON", "CRM", "NFLX", "0941.HK", "T", "HSBC", "RY", "SAP", "UPS", "3690.HK", "IBM", "CAT", "UL", "QCOM", "BA", "LMT", "SIE.DE", "SAN.PA", "LOW", "CVS", "CBA.AX", "INTC", "BMW.DE", "GS", "LHA.DE", "MBG.DE", "AMCR", "MAR", "BAYN.DE", "RWE.DE", "PAH3.DE"]

endowment_after_trade = [] 
gewinn_liste = []  #Liste dient zur Speicherung der Gewinne der einzelnen Aktien
number_stocks = len(stocks)
#counter = 0
#virtual_today = datetime(2021, 4, 2)  #diese Variable dient zur Durchführung eines Testlaufes in der Vergangenheit (nicht bis zum aktuellen Tag sondern bis zu einem fiktiven heutigen Tag). Am Start der while-Schleife muss dementsprechdend today durch virtual_today ersetzt werden
#virtual_today = virtual_today.date()

#Counter, welche die Genauigkeit des Modells bestimmen
counter_right = 0
counter_general = 0

for stock in stocks:
    action = []  #dient zur Speicherung und Ausgabe der durchgeführten Handlungen mit der jeweiligen Aktie
    gewinn = 0  #gibt den Gewinn an, der mit jeweiliger Aktie erzielt wurde. Endwert wird an "gewinn_liste" übergeben
    gewinn_liste_aktie = [] #zeigt den Gewinnverlauf einer einzelnen Aktie an
    endowment_verlauf_aktie = []  #zeigt den Verlauf des Vermögens während des Tradings an (kann nur <= start_endowment sein da Gewinn ja abgeschöpft wird)  
    profit = 0
    min_start = datetime(2022, 6, 21)
    min_start = min_start.date()
    real_start = datetime(2022, 11, 4) #bildet zusammen mit "end" erstes Intervall welches auf Signifikanz geprüft wird, wird dann in jeder Iteration um einen Tag in die Vergangenheit verändert (bis min_start erreicht), bis signifikantes Zeitfenster gefunden
    real_start = real_start.date()
    end = datetime(2022, 12, 15) #gibt nur das ERSTE Enddatum an, wird sukzessive um einen Tag erhöht bis man bei "today" (oder "virtual_today" (hypothetisches Enddatum des Tests)) angekommen ist 
    end = end.date()
    print(stock)
    endowment = 10000.0  #Wie viel Geld soll in jeweilige Aktie investiert werden
    start_endowment = endowment
    cash = True #Zu Beginn startet man jeweils mit Bargeld

    data_1 = get_data(stock, min_start, today+timedelta(days=1))  #Download der Daten der Aktie für das komplette Zeitfenster

    while end != today:
        
        print(end)
        trading = False
        
        number_lags = 1
        counter = 0 #Hilfsvariable für Lag-Erhöhung
        real_start_change = real_start
        len_before = 0
        
        if np.is_busday(end) == True:  #Trading nur an Börsentagen
            while (trading == False) and (real_start_change != min_start):
                data = data_1[(data_1["Date"] >= str(real_start_change)) & (data_1["Date"]<= str(end+timedelta(days=1)))]
                df_train, df_test = split_one_day(data) #wird nicht zwingend benötigt
                lag, trading, highest_lag = statistic_tests(df_train["Log. Returns"], number_lags)
                real_start_change = real_start_change - timedelta(days=1)
                counter = counter + 1
                if number_lags < 11: #Maximalanzahl der zu prüfenden Lags 
                    #sukzessive Erhöhung der zu prüfenden Lags bei vergrößertem Zeitraum
                    if (len(data) % 5 == 0) and len_before != len(data):
                        number_lags = number_lags + 1
                len_before = len(data)
            
            if trading == True:
                df_train, df_test = split_one_day(data)
                endowment, action, profit, cash, gewinn, counter_right, counter_general = trade(df_train, df_test, endowment, profit, cash, gewinn, counter_right, counter_general)
            
            if trading == False:  #hier wird noch das jeweils größtmögliche Zeitfenster auf Signifikanz getestet. Falls sich doch noch Signifikanz ergibt wird getradet.
                df_train, df_test = split_one_day(data)
                endowment, action, profit, cash, gewinn, counter_right, counter_general = trade(df_train, df_test, endowment, profit, cash, gewinn, counter_right, counter_general)
                
            print(action)
            
            if endowment <= start_endowment*0.93:
                break

            gewinn_liste_aktie.append(gewinn)
            endowment_verlauf_aktie.append(endowment)
            
        else:
            print("No trading day (Weekend etc.)")
    
        #Verschiebung des kompletten Zeitfensters, damit anfängliche Zeitfenstergrößen unverändert bleiben
        min_start = min_start + timedelta(days=1)
        real_start = real_start + timedelta(days=1)
        end = end + timedelta(days=1)
        
        print(endowment)
    
    print(endowment)
    endowment_after_trade.append(endowment)
    gewinn_liste.append(gewinn)

print(endowment_after_trade)
# Out:
# AAPL
# [*********************100%***********************]  1 of 1 completed
# 2022-12-15
# ['No trade today, do nothing']
# 10000.0
# 2022-12-16
# ['No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-17
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-18
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-19
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-20
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-21
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-22
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-23
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-24
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-25
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-26
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-27
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-28
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-29
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT']
# 9970.311159330082
# 2022-12-30
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'SHORT']
# 9940.710461386197
# 2022-12-31
# No trading day (Weekend etc.)
# 9940.710461386197
# 2023-01-01
# No trading day (Weekend etc.)
# 9940.710461386197
# 2023-01-02
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2023-01-03
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9891.857686201727
# 2023-01-04
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2023-01-05
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9627.058982751843
# 2023-01-06
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9268.026465738296
# MSFT
# [*********************100%***********************]  1 of 1 completed
# 2022-12-15
# ['SHORT']
# 10000.0
# 2022-12-16
# ['SHORT', 'SHORT']
# 10000.0
# 2022-12-17
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-18
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-19
# ['SHORT', 'SHORT', 'SHORT']
# 9938.855016816398
# 2022-12-20
# ['SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9825.78349981668
# 2022-12-21
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2022-12-22
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9972.329305151434
# 2022-12-23
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9944.735177038208
# 2022-12-24
# No trading day (Weekend etc.)
# 9944.735177038208
# 2022-12-25
# No trading day (Weekend etc.)
# 9944.735177038208
# 2022-12-26
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2022-12-27
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2022-12-28
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9718.702905331225
# 2022-12-29
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9804.956420612725
# 2022-12-30
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9880.49980341694
# 2022-12-31
# No trading day (Weekend etc.)
# 9880.49980341694
# 2023-01-01
# No trading day (Weekend etc.)
# 9880.49980341694
# 2023-01-02
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9889.090580646633
# 2023-01-03
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2023-01-04
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2023-01-05
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing']
# 10000.0
# 2023-01-06
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2023-01-07
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-08
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-09
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT']
# 9918.82832760121
# 2023-01-10
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'SHORT']
# 9613.94200920112
# 2023-01-11
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'SHORT', 'SHORT']
# 9497.407054391519
# 2023-01-12
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'SHORT', 'SHORT', 'BUY']
# 9521.32861554994
# 2023-01-13
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD']
# 9550.071093365541
# 2023-01-14
# No trading day (Weekend etc.)
# 9550.071093365541
# 2023-01-15
# No trading day (Weekend etc.)
# 9550.071093365541
# 2023-01-16
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'HOLD']
# 9594.781952818406
# 2023-01-17
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'HOLD', 'SELL']
# 9589.984561841997
# 2023-01-18
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'HOLD', 'SELL', 'BUY']
# 9427.396484826415
# 2023-01-19
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'HOLD', 'SELL', 'BUY', 'SELL']
# 9422.682786584002
# 2023-01-20
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'HOLD', 'SELL', 'BUY', 'SELL', 'SHORT']
# 9081.171017114697
# GOOG
# [*********************100%***********************]  1 of 1 completed
# 2022-12-15
# ['SHORT']
# 10000.0
# 2022-12-16
# ['SHORT', 'SHORT']
# 10000.0
# 2022-12-17
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-18
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-19
# ['SHORT', 'SHORT', 'SHORT']
# 9941.15864056943
# 2022-12-20
# ['SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9867.4215115422
# 2022-12-21
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2022-12-22
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9819.383029135797
# 2022-12-23
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9642.02830728801
# 2022-12-24
# No trading day (Weekend etc.)
# 9642.02830728801
# 2022-12-25
# No trading day (Weekend etc.)
# 9642.02830728801
# 2022-12-26
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2022-12-27
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2022-12-28
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9707.005795727944
# 2022-12-29
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9745.314060064224
# 2022-12-30
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9783.773506252799
# 2022-12-31
# No trading day (Weekend etc.)
# 9783.773506252799
# 2023-01-01
# No trading day (Weekend etc.)
# 9783.773506252799
# 2023-01-02
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9671.925716864303
# 2023-01-03
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9875.747350210951
# 2023-01-04
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2023-01-05
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9834.805569572529
# 2023-01-06
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9672.340059129483
# 2023-01-07
# No trading day (Weekend etc.)
# 9672.340059129483
# 2023-01-08
# No trading day (Weekend etc.)
# 9672.340059129483
# 2023-01-09
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9619.578446534904
# 2023-01-10
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9289.22889147528
# AMZN
# [*********************100%***********************]  1 of 1 completed
# 2022-12-15
# ['SHORT']
# 10000.0
# 2022-12-16
# ['SHORT', 'SHORT']
# 10000.0
# 2022-12-17
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-18
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-19
# ['SHORT', 'SHORT', 'SHORT']
# 9963.20486595822
# 2022-12-20
# ['SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9773.438600219315
# 2022-12-21
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2022-12-22
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9820.75497451724
# 2022-12-23
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9644.722826950512
# 2022-12-24
# No trading day (Weekend etc.)
# 9644.722826950512
# 2022-12-25
# No trading day (Weekend etc.)
# 9644.722826950512
# 2022-12-26
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2022-12-27
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2022-12-28
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9706.561889616964
# 2022-12-29
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9734.1718308817
# 2022-12-30
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9761.860307560448
# 2022-12-31
# No trading day (Weekend etc.)
# 9761.860307560448
# 2023-01-01
# No trading day (Weekend etc.)
# 9761.860307560448
# 2023-01-02
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9545.472439541469
# 2023-01-03
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9668.505598391264
# 2023-01-04
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2023-01-05
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9638.88847609917
# 2023-01-06
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9290.817105467737
# JNJ
# [*********************100%***********************]  1 of 1 completed
# 2022-12-15
# ['BUY']
# 9892.45860229359
# 2022-12-16
# ['BUY', 'HOLD']
# 9791.01994911039
# 2022-12-17
# No trading day (Weekend etc.)
# 9791.01994911039
# 2022-12-18
# No trading day (Weekend etc.)
# 9791.01994911039
# 2022-12-19
# ['BUY', 'HOLD', 'HOLD']
# 9801.621258316465
# 2022-12-20
# ['BUY', 'HOLD', 'HOLD', 'HOLD']
# 9913.7702028867
# 2022-12-21
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9877.503372693931
# 2022-12-22
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9902.61124370231
# 2022-12-23
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9927.782937031247
# 2022-12-24
# No trading day (Weekend etc.)
# 9927.782937031247
# 2022-12-25
# No trading day (Weekend etc.)
# 9927.782937031247
# 2022-12-26
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9924.985892541778
# 2022-12-27
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9881.914650848892
# 2022-12-28
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9932.25803750677
# 2022-12-29
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9881.354729828114
# 2022-12-30
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9830.71230408817
# 2022-12-31
# No trading day (Weekend etc.)
# 9830.71230408817
# 2023-01-01
# No trading day (Weekend etc.)
# 9830.71230408817
# 2023-01-02
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9916.415001365569
# 2023-01-03
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2023-01-04
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9926.164337145277
# 2023-01-05
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2023-01-06
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2023-01-07
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-08
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-09
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9976.079384635761
# 2023-01-10
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks']
# 9971.091344943443
# 2023-01-11
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing']
# 9971.091344943443
# 2023-01-12
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing']
# 9971.091344943443
# 2023-01-13
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 9971.091344943443
# 2023-01-14
# No trading day (Weekend etc.)
# 9971.091344943443
# 2023-01-15
# No trading day (Weekend etc.)
# 9971.091344943443
# 2023-01-16
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT']
# 10000.0
# 2023-01-17
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'BUY']
# 9844.152582135726
# 2023-01-18
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'BUY', 'HOLD']
# 9830.815440828015
# 2023-01-19
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'BUY', 'HOLD', 'HOLD']
# 9785.004798160722
# 2023-01-20
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'BUY', 'HOLD', 'HOLD', 'HOLD']
# 9739.407628627396
# 2023-01-21
# No trading day (Weekend etc.)
# 9739.407628627396
# 2023-01-22
# No trading day (Weekend etc.)
# 9739.407628627396
# 2023-01-23
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks']
# 9734.537924813081
# 2023-01-24
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing']
# 9734.537924813081
# 2023-01-25
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing']
# 9734.537924813081
# 2023-01-26
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 9734.537924813081
# 2023-01-27
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'SHORT', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 9734.537924813081
# 2023-01-28
# No trading day (Weekend etc.)
# 9734.537924813081
# 9734.537924813081
# UNH
# [*********************100%***********************]  1 of 1 completed
# 2022-12-15
# ['SHORT']
# 10000.0
# 2022-12-16
# ['SHORT', 'SHORT']
# 10000.0
# 2022-12-17
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-18
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-19
# ['SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2022-12-20
# ['SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9854.096216045742
# 2022-12-21
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9861.051697586281
# 2022-12-22
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9777.17194647122
# 2022-12-23
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9694.005690514981
# 2022-12-24
# No trading day (Weekend etc.)
# 9694.005690514981
# 2022-12-25
# No trading day (Weekend etc.)
# 9694.005690514981
# 2022-12-26
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY']
# 9701.565480123889
# 2022-12-27
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD']
# 9637.009136469105
# 2022-12-28
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL']
# 9632.19063190087
# 2022-12-29
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY']
# 9632.827732747242
# 2022-12-30
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD']
# 9638.281289599674
# 2022-12-31
# No trading day (Weekend etc.)
# 9638.281289599674
# 2023-01-01
# No trading day (Weekend etc.)
# 9638.281289599674
# 2023-01-02
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD']
# 9428.492999132523
# 2023-01-03
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD', 'SELL']
# 9423.778752632956
# 2023-01-04
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD', 'SELL', 'SHORT']
# 9957.553481665203
# 2023-01-05
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD', 'SELL', 'SHORT', 'SHORT']
# 9951.761603379895
# 2023-01-06
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD', 'SELL', 'SHORT', 'SHORT', 'SHORT']
# 9945.973093979737
# 2023-01-07
# No trading day (Weekend etc.)
# 9945.973093979737
# 2023-01-08
# No trading day (Weekend etc.)
# 9945.973093979737
# 2023-01-09
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD', 'SELL', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2023-01-10
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD', 'SELL', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9842.736751101143
# 2023-01-11
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD', 'SELL', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9792.531221918247
# 2023-01-12
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD', 'SELL', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2023-01-13
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD', 'SELL', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2023-01-14
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-15
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-16
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD', 'SELL', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing']
# 10000.0
# 2023-01-17
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD', 'SELL', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'SHORT']
# 10000.0
# 2023-01-18
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD', 'SELL', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'SHORT', 'No trade today, do nothing']
# 10000.0
# 2023-01-19
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD', 'SELL', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'SHORT', 'No trade today, do nothing', 'SHORT']
# 9946.275581375128
# 2023-01-20
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD', 'SELL', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'SHORT', 'No trade today, do nothing', 'SHORT', 'SHORT']
# 9892.839794065912
# 2023-01-21
# No trading day (Weekend etc.)
# 9892.839794065912
# 2023-01-22
# No trading day (Weekend etc.)
# 9892.839794065912
# 2023-01-23
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD', 'SELL', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'SHORT', 'No trade today, do nothing', 'SHORT', 'SHORT', 'SHORT']
# 9769.987964175178
# 2023-01-24
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD', 'SELL', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'SHORT', 'No trade today, do nothing', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9747.216620666413
# 2023-01-25
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD', 'SELL', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'SHORT', 'No trade today, do nothing', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9742.738620977994
# 2023-01-26
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD', 'SELL', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'SHORT', 'No trade today, do nothing', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 9955.140794468449
# 2023-01-27
# ['SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'BUY', 'HOLD', 'SELL', 'BUY', 'HOLD', 'HOLD', 'SELL', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'No trade today, do nothing', 'SHORT', 'No trade today, do nothing', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT', 'SHORT']
# 10000.0
# 2023-01-28
# No trading day (Weekend etc.)
# 10000.0
# 10000.0
# XOM
# [*********************100%***********************]  1 of 1 completed
# 2022-12-15
# ['No trade today, do nothing']
# 10000.0
# 2022-12-16
# ['No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-17
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-18
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-19
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-20
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-21
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-22
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-23
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-24
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-25
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-26
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-27
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-28
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-29
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-30
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-31
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-01
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-02
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2023-01-03
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2023-01-04
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2023-01-05
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2023-01-06
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2023-01-07
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-08
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-09
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2023-01-10
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY']
# 10000.0
# 2023-01-11
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'HOLD']
# 10000.0
# 2023-01-12
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'HOLD', 'HOLD']
# 9993.817373779411
# 2023-01-13
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'HOLD', 'HOLD', 'HOLD']
# 9987.638570045521
# 2023-01-14
# No trading day (Weekend etc.)
# 9987.638570045521
# 2023-01-15
# No trading day (Weekend etc.)
# 9987.638570045521
# 2023-01-16
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks']
# 9982.644750760499
# 2023-01-17
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing']
# 9982.644750760499
# 2023-01-18
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'BUY']
# 10000.0
# 2023-01-19
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'BUY', 'HOLD']
# 10000.0
# 2023-01-20
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'BUY', 'HOLD', 'HOLD']
# 10000.0
# 2023-01-21
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-22
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-23
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'BUY', 'HOLD', 'HOLD', 'No trade today, sell stocks']
# 9995.0
# 2023-01-24
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'BUY', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'BUY']
# 9937.309547908926
# 2023-01-25
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'BUY', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'BUY', 'No trade today, sell stocks']
# 9932.340893134971
# 2023-01-26
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'BUY', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'BUY', 'No trade today, sell stocks', 'BUY']
# 9746.035153323539
# 2023-01-27
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'No trade today, do nothing', 'BUY', 'HOLD', 'HOLD', 'No trade today, sell stocks', 'BUY', 'No trade today, sell stocks', 'BUY', 'HOLD']
# 9568.097058292984
# 2023-01-28
# No trading day (Weekend etc.)
# 9568.097058292984
# 9568.097058292984
# V
# [*********************100%***********************]  1 of 1 completed
# 2022-12-15
# ['No trade today, do nothing']
# 10000.0
# 2022-12-16
# ['No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-17
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-18
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-19
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-20
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-21
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-22
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-23
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-24
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-25
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-26
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-27
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-28
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-29
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-30
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2022-12-31
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-01
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-02
# ['No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 10000.0
# 2023-01-03
# ...
# 9770.680827241822
# 2022-12-27
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY']
# 10000.0
# 2022-12-28
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks']
# 9995.0
# 2022-12-29
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing']
# 9995.0
# 2022-12-30
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing']
# 9995.0
# 2022-12-31
# No trading day (Weekend etc.)
# 9995.0
# 2023-01-01
# No trading day (Weekend etc.)
# 9995.0
# 2023-01-02
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing']
# 9995.0
# 2023-01-03
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY']
# 10000.0
# 2023-01-04
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks']
# 9995.0
# 2023-01-05
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'BUY']
# 9990.0025
# 2023-01-06
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'BUY', 'HOLD']
# 9990.0025
# 2023-01-07
# No trading day (Weekend etc.)
# 9990.0025
# 2023-01-08
# No trading day (Weekend etc.)
# 9990.0025
# 2023-01-09
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'BUY', 'HOLD', 'HOLD']
# 9970.022037693978
# 2023-01-10
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'BUY', 'HOLD', 'HOLD', 'HOLD']
# 9970.022037693978
# 2023-01-11
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2023-01-12
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2023-01-13
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2023-01-14
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-15
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-16
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9921.41461561118
# 2023-01-17
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2023-01-18
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9980.353185496957
# 2023-01-19
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2023-01-20
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2023-01-21
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-22
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-23
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2023-01-24
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2023-01-25
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2023-01-26
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2023-01-27
# ['No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'SHORT', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'No trade today, do nothing', 'No trade today, do nothing', 'No trade today, do nothing', 'BUY', 'No trade today, sell stocks', 'BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2023-01-28
# No trading day (Weekend etc.)
# 10000.0
# 10000.0
# SCHW
# [*********************100%***********************]  1 of 1 completed
# 2022-12-15
# ['BUY']
# 10000.0
# 2022-12-16
# ['BUY', 'HOLD']
# 10000.0
# 2022-12-17
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-18
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-19
# ['BUY', 'HOLD', 'HOLD']
# 10000.0
# 2022-12-20
# ['BUY', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2022-12-21
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9944.615760216346
# 2022-12-22
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2022-12-23
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2022-12-24
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-25
# No trading day (Weekend etc.)
# 10000.0
# 2022-12-26
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2022-12-27
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2022-12-28
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2022-12-29
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2022-12-30
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2022-12-31
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-01
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-02
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9841.46052594805
# 2023-01-03
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2023-01-04
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9971.206014617499
# 2023-01-05
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2023-01-06
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2023-01-07
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-08
# No trading day (Weekend etc.)
# 10000.0
# 2023-01-09
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 10000.0
# 2023-01-10
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9743.050162688234
# 2023-01-11
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9750.058476874567
# 2023-01-12
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9691.660908086826
# 2023-01-13
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9633.613109102867
# 2023-01-14
# No trading day (Weekend etc.)
# 9633.613109102867
# 2023-01-15
# No trading day (Weekend etc.)
# 9633.613109102867
# 2023-01-16
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9692.82122633434
# 2023-01-17
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 9447.859443762907
# 2023-01-18
# ['BUY', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD', 'HOLD']
# 8860.416001481772
# RTX
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [15], in <cell line: 17>()
#      31 start_endowment = endowment
#      32 cash = True #Zu Beginn startet man jeweils mit Bargeld
# ---> 34 data_1 = get_data(stock, min_start, today+timedelta(days=1))  #Download der Daten der Aktie für das komplette Zeitfenster
#      36 while end != today:
#      38     print(end)
#
# Input In [8], in get_data(asset, start, end)
#       2 def get_data(asset, start, end):
#       3     ticker = asset
# ----> 4     data = yf.download(ticker, start=start, end=end)
#       6     # calculate returns and format df
#       7     data["Returns"] = 100 * data["Adj Close"].pct_change()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/multi.py:118, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, keepna, progress, period, show_errors, interval, prepost, proxy, rounding, timeout, **kwargs)
#     111         _download_one_threaded(ticker, period=period, interval=interval,
#     112                                start=start, end=end, prepost=prepost,
#     113                                actions=actions, auto_adjust=auto_adjust,
#     114                                back_adjust=back_adjust, keepna=keepna,
#     115                                progress=(progress and i > 0), proxy=proxy,
#     116                                rounding=rounding, timeout=timeout)
#     117     while len(shared._DFS) < len(tickers):
# --> 118         _time.sleep(0.01)
#     120 # download synchronously
#     121 else:
#     122     for i, ticker in enumerate(tickers):
#
# KeyboardInterrupt:

# %%
#Darstellung der Ergebnisse
print(sum(endowment_after_trade))
print(len(stocks)*start_endowment)
print(sum(gewinn_liste))
ergebnis = sum(endowment_after_trade)+ sum(gewinn_liste)
print(ergebnis)

if (len(stocks)*start_endowment) < ergebnis:
    print("Im ausgewählten Zeitraum wurde mit den ausgewählten Aktien ein Gewinn erwirtschaftet!")
